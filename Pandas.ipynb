# %% [markdown]
# <a href="https://colab.research.google.com/github/vlvsvenkat/DWDM/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({"Roll No":["AIML01","AIML02","AIML03"],"Name":["A.RAMU","B.RAJESH","B.SUBBU"]})
df
# Out:
#   Roll No      Name
# 0  AIML01    A.RAMU
# 1  AIML02  B.RAJESH
# 2  AIML03   B.SUBBU

# %%
df=pd.read_csv("/content/drive/MyDrive/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isna().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.shape
# Out:
# (150, 6)

# %%
host_day=pd.read_csv("/content/drive/MyDrive/Samsung.csv")
host_day.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close    Volume
# 0  2000-01-04  6000.0  6110.0  5660.0  6110.0  4651.737793  74195000
# 1  2000-01-05  5800.0  6060.0  5520.0  5580.0  4248.232422  74680000
# 2  2000-01-06  5750.0  5780.0  5580.0  5620.0  4278.686523  54390000
# 3  2000-01-07  5560.0  5670.0  5360.0  5540.0  4217.780273  40305000
# 4  2000-01-10  5600.0  5770.0  5580.0  5770.0  4392.884766  46880000

# %%
host_day.shape
# Out:
# (5621, 7)

# %%
df=pd.read_excel("/content/drive/MyDrive/students_placement_data.xlsx")
df
# Out:
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A            87.3                     65.30
# 1          2      F       A            89.0                     92.40
# 2          3      F       A            67.0                     40.20
# 3          4      M       A            71.0                     70.40
# 4          5      M       A            44.0                     65.50
# ..       ...    ...     ...             ...                       ...
# 112      113      M       B            81.1                     78.60
# 113      114      M       B            81.3                     85.12
# 114      115      M       B            83.5                     89.90
# 115      116      M       B            85.5                     90.63
# 116      117      M       B            80.0                     83.33
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# ...

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/students_placement_data.xlsx")
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                      True
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.153362                 80.535299
# std     33.919021        9.462320                 11.818567
# min      1.000000       44.000000                 40.200000
# 25%     30.000000       75.875000                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         116.000000  117.000000
# mean           62.662672    4.111111
# std            12.591167    6.335148
# min            21.200000    0.000000
# 25%            54.175000    0.000000
# 50%            63.885000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
df=pd.read_excel("/content/drive/MyDrive/students_placement_data.xlsx")
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                      True
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.153362                 80.535299
# std     33.919021        9.462320                 11.818567
# min      1.000000       44.000000                 40.200000
# 25%     30.000000       75.875000                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         116.000000  117.000000
# mean           62.662672    4.111111
# std            12.591167    6.335148
# min            21.200000    0.000000
# 25%            54.175000    0.000000
# 50%            63.885000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                      True
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.153362                 80.535299
# std     33.919021        9.462320                 11.818567
# min      1.000000       44.000000                 40.200000
# 25%     30.000000       75.875000                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         116.000000  117.000000
# mean           62.662672    4.111111
# std            12.591167    6.335148
# min            21.200000    0.000000
# 25%            54.175000    0.000000
# 50%            63.885000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
df["SSC Percentage"].mean()
# Out:
# 80.1533620689655

# %%
df["SSC Percentage"]=df["SSC Percentage"].fillna(df["SSC Percentage"].mean())
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A       87.300000                      65.3
# 1        2      F       A       89.000000                      92.4
# 2        3      F       A       67.000000                      40.2
# 4        5      M       A       44.000000                      65.5
# 5        6      M       A       80.389569                      68.0
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.05        18                                 NO
# 1              21.25         0                                yes
# 2                NaN        13                                yes
# 4              42.57        17                                yes
# 5              62.25         6                                yes
#
#   placement status hostler/days scholar
# 0       Not placed                  NaN
# 1           Placed                    h
# ...

# %%
df["SSC Percentage"].mean()
# Out:
# 80.15336206896552

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=df["SSC Percentage"]
y=df["inter_Diploma_percentage"]
plt.scatter(x, y)
plt.show()

# %%
df1=pd.DataFrame({'Roll No': [118],'Gender': ["F"],
'Section': ["C"], "SSC Percentage": [98.4],
'inter_Diploma_percentage':[99],'B.Tech_percentage':[75],
'Backlogs': [0], 'placement status': ["Not placed"],
"hostler/days scholar":["h"]},index=[117])
df1
# Out:
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 117      118      F       C            98.4                        99
#
#      B.Tech_percentage  Backlogs placement status hostler/days scholar
# 117                 75         0       Not placed                    h

# %%
df=df.append(df1)
df.tail()
# Out:
# <ipython-input-27-7e075627229f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df1)
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 113      114      M       B            81.3                     85.12
# 114      115      M       B            83.5                     89.90
# 115      116      M       B            85.5                     90.63
# 116      117      M       B            80.0                     83.33
# 117      118      F       C            98.4                     99.00
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 113              68.50         0                                 NO
# 114              76.30         0                                 NO
# 115              74.50         0                                 NO
# 116              65.53         0                                 NO
# ...

# %%
df=df.drop(3)
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 4        5      M       A            44.0                      65.5
# 5        6      M       A             NaN                      68.0
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 4              42.52        17                                yes
# 5              62.20         6                                yes
#
#   placement status hostler/days scholar
# 0       Not placed                  NaN
# 1           Placed                  NaN
# ...

# %%
df.loc[1,'hostler/days scholar']="h"
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 4        5      M       A            44.0                      65.5
# 5        6      M       A             NaN                      68.0
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 4              42.52        17                                yes
# 5              62.20         6                                yes
#
#   placement status hostler/days scholar
# 0       Not placed                  NaN
# 1           Placed                    h
# ...

# %%
def incre(x):
    if(x<70):
        return(x+0.05)
    else:
        return(x)

# %%
df["B.Tech_percentage"]=df["B.Tech_percentage"].apply(incre)
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 4        5      M       A            44.0                      65.5
# 5        6      M       A             NaN                      68.0
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.05        18                                 NO
# 1              21.25         0                                yes
# 2                NaN        13                                yes
# 4              42.57        17                                yes
# 5              62.25         6                                yes
#
#   placement status hostler/days scholar
# 0       Not placed                  NaN
# 1           Placed                    h
# ...

# %%
del df["registered_for_ Placement_Training"]
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A       87.300000                      65.3
# 1        2      F       A       89.000000                      92.4
# 2        3      F       A       67.000000                      40.2
# 4        5      M       A       44.000000                      65.5
# 5        6      M       A       80.389569                      68.0
#
#    B.Tech_percentage  Backlogs placement status hostler/days scholar
# 0              40.05        18       Not placed                  NaN
# 1              21.25         0           Placed                    h
# 2                NaN        13       Not placed                  NaN
# 4              42.57        17       Not placed                  NaN
# 5              62.25         6       Not placed                  NaN

# %%
df["B.Tech_percentage"]=df["B.Tech_percentage"].apply(incre)
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A       87.300000                      65.3
# 1        2      F       A       89.000000                      92.4
# 2        3      F       A       67.000000                      40.2
# 4        5      M       A       44.000000                      65.5
# 5        6      M       A       80.389569                      68.0
#
#    B.Tech_percentage  Backlogs placement status hostler/days scholar
# 0              40.10        18       Not placed                  NaN
# 1              21.30         0           Placed                    h
# 2                NaN        13       Not placed                  NaN
# 4              42.62        17       Not placed                  NaN
# 5              62.30         6       Not placed                  NaN

# %%
for index,rows in df[df["B.Tech_percentage"]>=80].iterrows():
    print(rows["Roll No"],"-",rows["B.Tech_percentage"])
# Out:
# 18 - 85.39
# 60 - 81.1
# 71 - 80.47
# 97 - 88.1
# 102 - 83.38

# %%
df.loc[[1,2],["SSC Percentage","inter_Diploma_percentage"]]
# Out:
#    SSC Percentage  inter_Diploma_percentage
# 1            89.0                      92.4
# 2            67.0                      40.2

# %%
df["SSC Percentage"]=df["SSC Percentage"].replace(to_replace=np.nan,value=np.mean(df["SSC Percentage"]))
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df["B.Tech_percentage"] = df["B.Tech_percentage"].fillna(df["B.Tech_percentage"].mean())
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2              51.00        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df

# %%
df["registered_for_ Placement_Training"] = df["registered_for_ Placement_Training"].fillna(df["registered_for_ Placement_Training"].mode())
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2              51.00        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df["inter_Diploma_percentage"] = df["inter_Diploma_percentage"].fillna(df["inter_Diploma_percentage"].median())
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
grouped=df.groupby("Gender")
grouped["B.Tech_percentage"].agg(np.mean)
# Out:
# Gender
# F    70.291020
# M    56.994265
# Name: B.Tech_percentage, dtype: float64

# %%
df["registered_for_ Placement_Training"] = df["registered_for_ Placement_Training"].fillna(df["registered_for_ Placement_Training"].mode())
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                        False
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
x=df["SSC Percentage"]
y=df["inter_Diploma_percentage"]
plt.scatter(x, y)
plt.show()

# %%
print(df['Gender'].value_counts())
print(df['Section'].value_counts())
print(df['registered_for_ Placement_Training'].value_counts())
print(df['placement status'].value_counts())
# Out:
# M    68
# F    49
# Name: Gender, dtype: int64
# A    60
# B    57
# Name: Section, dtype: int64
# yes    67
# NO     49
# Name: registered_for_ Placement_Training, dtype: int64
# Not placed    78
# Placed        39
# Name: placement status, dtype: int64

# %%
pd.crosstab(index=df['Gender'],columns=df['placement status'])
# Out:
# placement status  Not placed  Placed
# Gender
# F                         20      29
# M                         58      10

# %%
import plotly.express as px
cut_counts=df['Gender'].value_counts()
fig=px.scatter(x=cut_counts.index,y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
cut_counts=df['Gender'].value_counts()
fig=px.bar(x=cut_counts.index,y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pd.pivot_table(df, values='B.Tech_percentage',index='Gender',columns='placement status',aggfunc=np.mean)
# Out:
# placement status  Not placed     Placed
# Gender
# F                  65.592500  73.531379
# M                  54.825345  69.574000

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[["Gender","Section","SSC Percentage","inter_Diploma_percentage","B.Tech_percentage","Backlogs","registered_for_ Placement_Training"]].values
y=df["placement status"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
plt.scatter(x, y)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
cols_to_scale=["SSC Percentage","inter_Diploma_percentage","B.Tech_percentage"]
scaler=StandardScaler()
scaler.fit(df[cols_to_scale])
df[cols_to_scale]=scaler.transform(df[cols_to_scale])
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A        0.758550                 -1.294643
# 1        2      F       A        0.938989                  1.008221
# 2        3      F       A       -1.396109                 -3.427555
# 3        4      M       A       -0.971545                 -0.861263
# 4        5      M       A       -3.837348                 -1.277648
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0          -1.807695        18                                 NO
# 1          -3.307283         0                                yes
# 2                NaN        13                                yes
# 3          -2.089267        17                                yes
# 4          -1.606687        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed
